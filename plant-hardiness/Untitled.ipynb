# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
df_2012 = pd.read_csv('https://prism.oregonstate.edu/projects/public/phm/2012/phm_us_zipcode_2012.csv',
                      usecols=['zone', 'trange', 'zipcode'],
                      dtype={'zipcode':str},
                      index_col='zipcode')

# %%
df_2023 = pd.read_csv('https://prism.oregonstate.edu/projects/phm_data/phzm_us_zipcode_2023.csv',
                      usecols=['zone', 'trange', 'zipcode'],
                     dtype={'zipcode':str},
                     index_col='zipcode')

# %%
df_2012
# Out:
#         zone      trange
# zipcode
# 01001     6a   -10 to -5
# 01002     5b  -15 to -10
# 01003     5b  -15 to -10
# 01004     5b  -15 to -10
# 01005     5b  -15 to -10
# ...      ...         ...
# 99363     7a      0 to 5
# 99371     6b     -5 to 0
# 99401     6b     -5 to 0
# 99402     7a      0 to 5
# 99403     7b     5 to 10
#
# [40534 rows x 2 columns]

# %%
df_2023
# Out:
#         zone     trange
# zipcode
# 00501     7b    5 to 10
# 00544     7b    5 to 10
# 01001     6b    -5 to 0
# 01002     6a  -10 to -5
# 01003     6a  -10 to -5
# ...      ...        ...
# 99363     7b    5 to 10
# 99371     7a     0 to 5
# 99401     7a     0 to 5
# 99402     7a     0 to 5
# 99403     7b    5 to 10
#
# [39921 rows x 2 columns]

# %%
zip_code_csv = pd.read_csv('http://uszipcodelist.com/zip_code_database.csv',
                          dtype={'zip':str},
                          index_col='zip')

# %%
zip_code_csv
# Out:
#            type primary_city acceptable_cities  \
# zip
# 00501    UNIQUE   Holtsville               NaN
# 00544    UNIQUE   Holtsville               NaN
# 00601  STANDARD     Adjuntas               NaN
# 00602  STANDARD       Aguada               NaN
# 00603  STANDARD    Aguadilla             Ramey
# ...         ...          ...               ...
# 99926    PO BOX   Metlakatla               NaN
# 99927    PO BOX  Point Baker               NaN
# 99928    PO BOX    Ward Cove               NaN
# 99929    PO BOX     Wrangell               NaN
# 99950    PO BOX    Ketchikan  Edna Bay, Kasaan
#
#                                      unacceptable_cities state  \
# zip
# 00501                               I R S Service Center    NY
# 00544                                 Irs Service Center    NY
# 00601  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 00602  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 00603  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
# ...                                                  ...   ...
# 99926                                                NaN    AK
# 99927                                                NaN    AK
# 99928                                                NaN    AK
# 99929                                                NaN    AK
# 99950                                                NaN    AK
#
#                                         county             timezone  \
# zip
# 00501                           Suffolk County     America/New_York
# 00544                           Suffolk County     America/New_York
# 00601                                 Adjuntas  America/Puerto_Rico
# 00602                                      NaN                  NaN
# 00603                                Aguadilla  America/Puerto_Rico
# ...                                        ...                  ...
# 99926  Prince of Wales-Outer Ketchikan Borough       America/Juneau
# 99927  Prince of Wales-Outer Ketchikan Borough       America/Juneau
# 99928                Ketchikan Gateway Borough       America/Juneau
# 99929                         Wrangell Borough                  NaN
# 99950  Prince of Wales-Outer Ketchikan Borough       America/Juneau
#
#       area_codes  latitude  longitude world_region country  decommissioned  \
# zip
# 00501        631     40.81     -73.04          NaN      US               0
# 00544        631     40.81     -73.04          NaN      US               0
# 00601    787,939     18.16     -66.72          NaN      US               0
# 00602        787     18.38     -67.18          NaN      US               0
# 00603        787     18.43     -67.15          NaN      US               0
# ...          ...       ...        ...          ...     ...             ...
# 99926        907     55.14    -131.49          NaN      US               0
# 99927        907     56.30    -133.57          NaN      US               0
# 99928        907     55.45    -131.79          NaN      US               0
# 99929        907     55.95    -131.96          NaN      US               0
# 99950        907     55.34    -131.64          NaN      US               0
#
#        estimated_population          notes
# zip
# 00501                   384            NaN
# 00544                     0            NaN
# 00601                     0            NaN
# 00602                     0            NaN
# 00603                     0            NaN
# ...                     ...            ...
# 99926                  1018            NaN
# 99927                     0            NaN
# 99928                  1281            NaN
# 99929                  1956            NaN
# 99950                     0  no NWS data,
#
# [42522 rows x 15 columns]

# %%
md = zip_code_csv[zip_code_csv['state'] == 'MD']

# %%
md
# Out:
#            type primary_city     acceptable_cities unacceptable_cities state  \
# zip
# 20588    UNIQUE          Dhs  Cheltenham, Columbia             Dept Hs    MD
# 20601  STANDARD      Waldorf                   NaN                 NaN    MD
# 20602  STANDARD      Waldorf         Saint Charles                 NaN    MD
# 20603  STANDARD      Waldorf         Saint Charles                 NaN    MD
# 20604    PO BOX      Waldorf         Saint Charles                 NaN    MD
# ...         ...          ...                   ...                 ...   ...
# 21919  STANDARD   Earleville                   NaN                 NaN    MD
# 21920    PO BOX    Elk Mills                   NaN                 NaN    MD
# 21921  STANDARD       Elkton                   NaN                 NaN    MD
# 21922    PO BOX       Elkton                   NaN                 NaN    MD
# 21930    PO BOX   Georgetown                   NaN                 NaN    MD
#
#                county          timezone area_codes  latitude  longitude  \
# zip
# 20588   Howard County  America/New_York        410     38.74     -76.85
# 20601  Charles County  America/New_York    304,301     38.64     -76.90
# 20602  Charles County  America/New_York    301,240     38.64     -76.90
# 20603  Charles County  America/New_York    301,240     38.64     -76.90
# 20604  Charles County  America/New_York        240     38.64     -76.90
# ...               ...               ...        ...       ...        ...
# 21919    Cecil County  America/New_York        410     39.41     -75.93
# 21920    Cecil County  America/New_York        410     39.65     -75.85
# 21921    Cecil County  America/New_York    443,410     39.60     -75.82
# 21922    Cecil County  America/New_York        410     39.60     -75.82
# 21930    Cecil County  America/New_York        410     39.39     -75.87
#
#       world_region country  decommissioned  estimated_population  \
# zip
# 20588          NaN      US               0                     0
# 20601          NaN      US               0                 20090
# 20602          NaN      US               0                 18650
# 20603          NaN      US               0                 22217
# 20604          NaN      US               0                  1178
# ...            ...     ...             ...                   ...
# 21919          NaN      US               0                  2486
# 21920          NaN      US               0                     0
# 21921          NaN      US               0                 33457
# 21922          NaN      US               0                   752
# 21930          NaN      US               0                     0
#
#                notes
# zip
# 20588  no NWS data,
# 20601            NaN
# 20602            NaN
# 20603            NaN
# 20604            NaN
# ...              ...
# 21919            NaN
# 21920            NaN
# 21921            NaN
# 21922            NaN
# 21930            NaN
#
# [622 rows x 15 columns]
