# %%
import pandas as pd

# URL to the dataset
url = "https://fred.stlouisfed.org/series/GFDEBTN"

# Read the data into a Pandas DataFrame
df = pd.read_csv('GFDEBTN.csv')

# Display the DataFrame
df.head()
# Out:
#          DATE   GFDEBTN
# 0  1966-01-01  320999.0
# 1  1966-04-01  316097.0
# 2  1966-07-01  324748.0
# 3  1966-10-01  329319.0
# 4  1967-01-01  330947.0

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp311-cp311-win_amd64.whl (7.5 MB)
#                                               0.0/7.5 MB ? eta -:--:--
#                                               0.0/7.5 MB ? eta -:--:--
#                                               0.0/7.5 MB 262.6 kB/s eta 0:00:29
#                                               0.1/7.5 MB 469.7 kB/s eta 0:00:16
#      -                                        0.2/7.5 MB 1.3 MB/s eta 0:00:06
#      -----                                    1.0/7.5 MB 5.0 MB/s eta 0:00:02
#      ----------------                         3.1/7.5 MB 11.8 MB/s eta 0:00:01
#      -------------------                      3.6/7.5 MB 11.5 MB/s eta 0:00:01
#      -----------------------------------      6.6/7.5 MB 18.5 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.5 MB 20.0 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.5 MB 20.0 MB/s eta 0:00:01
#      ---------------------------------------- 7.5/7.5 MB 16.0 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.0-cp311-cp311-win_amd64.whl (470 kB)
#                                               0.0/470.9 kB ? eta -:--:--
#      ------------------------------------- 470.9/470.9 kB 14.9 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.41.1-cp311-cp311-win_amd64.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      ---------------------------------------  2.1/2.1 MB 65.3 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 33.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
#                                               0.0/55.4 kB ? eta -:--:--
#      ---------------------------------------- 55.4/55.4 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib) (10.0.0)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#                                               0.0/98.3 kB ? eta -:--:--
#      ---------------------------------------- 98.3/98.3 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.41.1 kiwisolver-1.4.4 matplotlib-3.7.2 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# Convert the "DATE" column to datetime format
df["DATE"] = pd.to_datetime(df["DATE"])

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(df["DATE"], df["GFDEBTN"])
plt.xlabel("Date")
plt.ylabel("Total Federal Debt (in trillions)")
plt.title("Total Federal Debt Over Time")
plt.grid(True)
plt.show()

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#                                               0.0/293.3 kB ? eta -:--:--
#      -                                        10.2/293.3 kB ? eta -:--:--
#      ---                                   30.7/293.3 kB 262.6 kB/s eta 0:00:01
#      -------                               61.4/293.3 kB 409.6 kB/s eta 0:00:01
#      -------------------------------------  286.7/293.3 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\embla\anaconda3\envs\lerner\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.
