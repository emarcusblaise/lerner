# %%
import pandas as pd
filename = 'GTI-2023-Overall-scores-2011-2022.xlsx'

df = (
    pd.read_excel(filename, 
                  sheet_name='Overall Scores',
                  header=6,
                 index_col='Country')
)

# %%
df
# Out:
#             Iso3c  2012 Rank  2012 Score  2013 Rank  2013 Score  2014 Rank  \
# Country
# Afghanistan   AFG          3    9.134265          3    8.935458          4
# Albania       ALB         97    0.826319         99    0.508313        105
# Algeria       DZA         14    6.695682         16    6.476254         20
# Angola        AGO         72    2.364660         82    1.657740         74
# Argentina     ARG         63    2.810899         66    2.581995         75
# ...           ...        ...         ...        ...         ...        ...
# Venezuela     VEN         69    2.408456         63    2.649197         80
# Vietnam       VNM        112    0.000000        110    0.000000        110
# Yemen         YEM          5    8.098513          6    7.983732          6
# Zambia        ZMB        112    0.000000        110    0.000000        110
# Zimbabwe      ZWE        112    0.000000        110    0.000000        110
#
# ...
