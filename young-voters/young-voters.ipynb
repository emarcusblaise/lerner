# %%
import pandas as pd

# %%
filename = 'Harvard IOP Youth Poll Spring 2023 Crosstabs.xlsx'
likely_voter_2024_df = pd.read_excel(filename, sheet_name=1, header=[0,1], skiprows=166, nrows=6, index_col=0)
likely_voter_2024_df
# Out:
#                            Unnamed: 1_level_0    Gender            \
# Likely voter 2024                         All      Male    Female
# Definitely will be voting            0.510648  0.538129  0.483354
# Probably will be voting              0.152669  0.147319  0.159466
# 50-50                                0.156682  0.135932  0.174063
# Probably won’t be voting             0.072579  0.069870  0.076488
# Definitely won’t be voting           0.099103  0.095552  0.103101
# Refused                              0.008320  0.013198  0.003527
#
#                            Age Category           Education Status  \
# Likely voter 2024                 18-24     25-29  College student
# Definitely will be voting      0.443967  0.615580         0.557401
# Probably will be voting        0.186113  0.101124         0.234618
# 50-50                          0.176414  0.122450         0.139195
# Probably won’t be voting       0.078126  0.072178         0.033960
# ...

# %%
likely_voter_2024_df.drop('All', level=1, axis='columns')
# Out:
#                               Gender           Age Category            \
# Likely voter 2024               Male    Female        18-24     25-29
# Definitely will be voting   0.538129  0.483354     0.443967  0.615580
# Probably will be voting     0.147319  0.159466     0.186113  0.101124
# 50-50                       0.135932  0.174063     0.176414  0.122450
# Probably won’t be voting    0.069870  0.076488     0.078126  0.072178
# Definitely won’t be voting  0.095552  0.103101     0.103334  0.084044
# Refused                     0.013198  0.003527     0.012047  0.004623
#
#                            Education Status                           \
# Likely voter 2024           College student Not in college/No degree
# Definitely will be voting          0.557401                 0.411495
# Probably will be voting            0.234618                 0.146322
# 50-50                              0.139195                 0.196681
# ...
